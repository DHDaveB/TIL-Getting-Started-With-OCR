# %%
import io
import os

# Set environment variable
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "resources/ocr-test-project-310004-9dee1d1595c2.json"

# Imports the Google Cloud client library
from google.cloud import vision

# Instantiates a client
client = vision.ImageAnnotatorClient()

# The name of the image file to annotate
#file_name = os.path.abspath('resources/picture1.png')
file_name = os.path.abspath('resources/picture2.jpg')


# Loads the image into memory
with io.open(file_name, 'rb') as image_file:
    content = image_file.read()

image = vision.Image(content=content)

# Performs label detection on the image file
response = client.label_detection(image=image)
labels = response.label_annotations

print('Labels:')
for label in labels:
    print(label.description)
# Out:
# Labels:
# Rectangle
# Font
# Material property
# Parallel
# Magenta
# Pattern
# Number
# Electric blue
# Graphic design
# Slope

# %%
# Performs text detection on the image file
response = client.text_detection(image=image)
texts = response.text_annotations

print('Texts:')
for text in texts:
    print(text.description)
# Out:
# Texts:
# B6동서울
# 451 00 00
# www.e POSTAA
# '우체국 택배'
# 접수국우경사업본부
# 신청일:2016/03/10
# 주문인 유지*
# 고객 주문처 :
# 문의처 : 080-000-0000
# 주문번호 :
# 중량: 5,000g 용적 : 60cm 요금: 계약요금
# 세종특별자치시 도움5로 19(어진동)
# 정부세종청사 8동
# 우정사업본부 우편사업단 우편신사업과
# 김상 *
# 30114
# T:044) 200-826*
# M:010) 0000-0000
# 동시배달
# (1/1)
# |서울시 종로구 세종대로 23 길21
# 광화문
# (구)서울시 종로구 당주동 145번지
# (당주동 15-7)
# 03183
# 홍길동님
# T:0507- s
# ·고객님의 개인정보를 위하여 임시 가상전화번호를 사용합니다.
# 등기번호 60153-43013197
# 테스트 상품,모델명,수량:1Size:사이즈1,
# 색상,주문번호12345
# M:010-0000-0000
# LOGO
# 신청 및 배달내1588-1300
# 배송메시지 : 부재시 경비실에 맡겨주세요.
# 보낸분
# 개인정보 유출방지를 위하여 성명, 전화번호, 주소를 제거 바랍니다.!
# 서울시 :
# 신 종로구 세종대로 23 길21
# 0000-0000 (0LO:W
#
# B6
# 동서울
# 451
# 00
# 00
# www.e
# POSTAA
# '
# 우체국
# 택배
# '
# 접수국
# 우경
# 사업
# 본부
# 신청일
# :
# 2016/03/10
# 주문
# 인
# 유지
# *
# 고객
# 주문처
# :
# 문의처
# :
# 080-000-0000
# 주문
# 번호
# :
# 중량
# :
# 5,000g
# 용적
# :
# 60cm
# 요금
# :
# 계약
# 요금
# 세종
# 특별
# 자치
# 시
# 도움
# 5
# 로
# 19
# (
# 어
# 진동
# )
# 정부
# 세종
# 청사
# 8
# 동
# 우정
# 사업
# 본부
# 우편
# 사업단
# 우편
# 신사업
# 과
# 김상
# *
# 30114
# T:044)
# 200-826*
# M:010)
# 0000-0000
# 동시
# 배달
# (1/1)
# |
# 서울시
# 종로구
# 세종대
# 로
# 23
# 길
# 21
# 광화문
# (
# 구
# )
# 서울시
# 종로구
# 당주동
# 145
# 번지
# (
# 당주동
# 15-7
# )
# 03183
# 홍길동
# 님
# T:0507-
# s
# ·
# 고객님
# 의
# 개인
# 정보
# 를
# 위하여
# 임시
# 가상
# 전화
# 번호
# 를
# 사용
# 합니다
# .
# 등기
# 번호
# 60153-43013197
# 테스트
# 상품
# ,
# 모델명
# ,
# 수량
# :
# 1Size
# :
# 사이즈
# 1
# ,
# 색상
# ,
# 주문
# 번호
# 12345
# M:010-0000-0000
# LOGO
# 신청
# 및
# 배달
# 내
# 1588-1300
# 배송
# 메시지
# :
# 부재시
# 경비실
# 에
# 맡겨
# 주세요
# .
# 보낸
# 분
# 개인
# 정보
# 유출
# 방지
# 를
# 위하여
# 성명
# ,
# 전화
# 번호
# ,
# 주소
# 를
# 제거
# 바랍니다
# .
# !
# 서울시
# :
# 신
# 종로구
# 세종대
# 로
# 23
# 길
# 21
# 0000-0000
# (0LO:W
